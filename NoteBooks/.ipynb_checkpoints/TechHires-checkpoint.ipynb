# %%
# import libraries
import pyodbc
import pandas as pd
import numpy as np

# %%
# fetch historical files.
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                      'Server=ulloadia25;'
                      'Database=HRAnalytics;'
                      'Trusted_Connection=yes;')

# read query
queryPath = 'C:/Users/garciand/OneDrive - HP Inc/Desktop/Python/DEI_Query.sql'
with open(queryPath, 'r') as getQuery:
    query = getQuery.read()

# %%
# run query
df = pd.read_sql_query(query,conn)

# %%
df = df.sort_values(by="Report Date")
df.loc[df['Technical Job Family'] == "Yes"]
df.loc[df['Is New Hire'] == "Yes"]
# Out:
#        Report Date Hybrid L1 Hybrid L2 Work Address - City  \
# 175071  2020-11-30      HPCS       CS1               Other
# 138873  2020-11-30      HCCO       SO1               Other
# 341022  2020-11-30       SBM       PRO               Other
# 248957  2020-11-30      HPCS       CS1               Other
# 284867  2020-11-30      HPCS       CS1               Other
# ...            ...       ...       ...                 ...
# 320004  2021-03-31      HCCO       GA1               Other
# 238155  2021-03-31      HPCS       CS1               Other
# 64424   2021-03-31       SBM       GRE               Other
# 160467  2021-03-31      HPIP       PFT               Other
# 65023   2021-03-31       FIN       OPF               Other
#
#        Technical Job Family Business Lvl 4 (MRU) Code Veteran Status  \
# 175071                   No                     Other              N
# 138873                   No                     Other              N
# 341022                   No                     Other              N
# 248957                  Yes                     Other              N
# 284867                  Yes                     Other              N
# ...                     ...                       ...            ...
# 320004                   No                     Other              N
# 238155                   No                     Other              U
# 64424                    No                     Other              N
# 160467                  Yes                     Other              N
# 65023                    No                     Other              N
#
#        PWD Status    Pay Group Country Desc Ethnicity Group Gender Code  \
# 175071          N                     Other           Other           M
# 138873          N                     Other           Other           F
# 341022          N                     Other           Other           F
# 248957          N  United States of America       ASIAN_USA           M
# 284867          U                     Other           Other           F
# ...           ...                       ...             ...         ...
# 320004          N                     Other           Other           U
# 238155          N                     Other           Other           F
# 64424           N  United States of America       WHITE_USA           F
# 160467          N                     Other           Other           M
# 65023           N                     Other           Other           M
#
#        Is Professional Is New Hire Management Level Category  HC  \
# 175071             Yes         Yes                      PROF   1
# 138873             Yes         Yes                      PROF   1
# 341022             Yes         Yes                      PROF   1
# 248957              No         Yes                      NONE   1
# 284867             Yes         Yes                      PROF   1
# ...                ...         ...                       ...  ..
# 320004             Yes         Yes                      PROF   1
# 238155             Yes         Yes                      PROF   1
# 64424              Yes         Yes                      PROF   1
# 160467             Yes         Yes                       MGR   2
# 65023              Yes         Yes                       MGR   1
#
#         Voluntary Attrits
# 175071                  0
# 138873                  0
# 341022                  0
# 248957                  0
# 284867                  0
# ...                   ...
# 320004                  0
# 238155                  0
# 64424                   0
# 160467                  0
# 65023                   0
#
# [1841 rows x 16 columns]

# %%
fdf.head()
# Out:
#   Report Date Hybrid L1 Hybrid L2 Work Address - City Technical Job Family  \
# 0  2019-11-30      HPIP       GSB               Other                  Yes
# 1  2019-12-31      HPCS       CS1               Other                  Yes
# 4  2018-07-31      OPER       SPN               Other                  Yes
# 6  2018-07-31      HPIP       GSB               Other                  Yes
# 8  2019-09-30      HPCS       CS1               Other                  Yes
#
#   Business Lvl 4 (MRU) Code Veteran Status PWD Status  \
# 0                     Other              Y          N
# 1                     Other              U          N
# 4                     Other              U          N
# 6                     Other              U          N
# 8                     Other              N          N
#
#      Pay Group Country Desc Ethnicity Group Gender Code Is Professional  \
# 0  United States of America       WHITE_USA           M              No
# 1  United States of America       HISPA_USA           M              No
# 4  United States of America       WHITE_USA           M             Yes
# 6                     Other           Other           F             Yes
# 8                     Other           Other           M              No
#
#   Is New Hire Management Level Category  HC  Voluntary Attrits
# 0          No                      NONE  15                  0
# 1          No                      NONE   1                  0
# 4          No                      PROF   1                  0
# 6          No                      PROF   1                  0
# 8          No                      NONE  11                  0
